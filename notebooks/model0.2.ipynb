# %%
import os
import sys
sys.path.append('../python_scripts/')
import keras
import tensorflow as tf
import get_frames as gf
import model_generator as mg
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
from importlib import reload as rd

# %% [markdown]
# <h1> GLOBAL VARIABLE </h1>

# %%
DATASET_PATH = '../dataset/'

# %% [markdown]
# <h1> CALL GENERATOR </h1>

# %%
rd(gf)
for X,Y in mg.SequentialWeatherGenerator(2,DATASET_PATH,size=(640,1280)):
    for i,x in enumerate(X):
        print(Y[i])
        plt.imshow(x)
        #gf.extract_map(x)
        plt.show()
        plt.imshow(gf.extract_map(x))
        plt.show()
    break
# Out:
# [  0.00000000e+00   0.00000000e+00  -5.11273754e-42]
# 640 1280 3
# [  0.00000000e+00   0.00000000e+00  -5.11273754e-42]
# 640 1280 3

# %% [markdown]
# <h1> CREATE MODEL </h1>
